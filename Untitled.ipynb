# %%
import pandas as pd

# %%
df = pd.read_csv('Reviews.csv')

# %%
df.head(2)
# Out:
#    Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...

# %%
df = df[['ProfileName','HelpfulnessNumerator','Time']]

# %%
df
# Out:
#                             ProfileName  HelpfulnessNumerator        Time
# 0                            delmartian                     1  1303862400
# 1                                dll pa                     0  1346976000
# 2       Natalia Corres "Natalia Corres"                     1  1219017600
# 3                                  Karl                     3  1307923200
# 4         Michael D. Bigham "M. Wassir"                     0  1350777600
# ...                                 ...                   ...         ...
# 568449                 Lettie D. Carter                     0  1299628800
# 568450                        R. Sawyer                     0  1331251200
# 568451                    pksd "pk_007"                     2  1329782400
# 568452          Kathy A. Welch "katwel"                     1  1331596800
# 568453                         srfell17                     0  1338422400
#
# [568454 rows x 3 columns]

# %%
df = pd.concat([df,df,df,df,df],axis = 0)

# %%
df
# Out:
#                             ProfileName  HelpfulnessNumerator        Time
# 0                            delmartian                     1  1303862400
# 1                                dll pa                     0  1346976000
# 2       Natalia Corres "Natalia Corres"                     1  1219017600
# 3                                  Karl                     3  1307923200
# 4         Michael D. Bigham "M. Wassir"                     0  1350777600
# ...                                 ...                   ...         ...
# 568449                 Lettie D. Carter                     0  1299628800
# 568450                        R. Sawyer                     0  1331251200
# 568451                    pksd "pk_007"                     2  1329782400
# 568452          Kathy A. Welch "katwel"                     1  1331596800
# 568453                         srfell17                     0  1338422400
#
# [2842270 rows x 3 columns]

# %%
df = pd.concat([df,df,df,df,df],axis = 0)

# %%
df
# Out:
#                             ProfileName  HelpfulnessNumerator        Time
# 0                            delmartian                     1  1303862400
# 1                                dll pa                     0  1346976000
# 2       Natalia Corres "Natalia Corres"                     1  1219017600
# 3                                  Karl                     3  1307923200
# 4         Michael D. Bigham "M. Wassir"                     0  1350777600
# ...                                 ...                   ...         ...
# 568449                 Lettie D. Carter                     0  1299628800
# 568450                        R. Sawyer                     0  1331251200
# 568451                    pksd "pk_007"                     2  1329782400
# 568452          Kathy A. Welch "katwel"                     1  1331596800
# 568453                         srfell17                     0  1338422400
#
# [14211350 rows x 3 columns]

# %%
df.to_csv('small_sample.csv',index = False)

# %%
# !ls
# Out:
# Reviews.csv      Untitled.ipynb   sample.csv       small_sample.csv
